# %%
import pandas as pd

# %%
path_to_csv = "../datasets/pokemon_data.csv"
df = pd.read_csv(path_to_csv)

# %%
df.head(1)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[["Name", "Type 1"]][:5]
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %%
df.iloc[:5, [1, 4]]
# Out:
#                     Name  HP
# 0              Bulbasaur  45
# 1                Ivysaur  60
# 2               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %%
df.loc[:4, ["Name", "HP"]]
# Out:
#                     Name  HP
# 0              Bulbasaur  45
# 1                Ivysaur  60
# 2               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %% [markdown]
# #### Notice the difference between iloc and loc methods: the range of rows in former is :5 while in latter is :4; the former works on indices while the latter works on names

# %%
for index, row in df.iterrows():
    print(index, row[["Name", "HP"]])
    break
# Out:
# 0 Name    Bulbasaur
# HP             45
# Name: 0, dtype: object

# %%
df.loc[df["Type 1"] == "Fire"].head(5)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df[df["Type 1"] == "Fire"].head(5)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.sort_values(["Type 1", "HP"], ascending=[False, True])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
# 97    90                 Shellder  Water       NaN  30      65      100
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# ..   ...                      ...    ...       ...  ..     ...      ...
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 698  637                Volcarona    Bug      Fire  85      60       65
# 520  469                  Yanmega    Bug    Flying  86      76       86
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df["Total"] = df.iloc[:, 4:10].sum(axis=1)

# %%
df.head(1)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary  Total
# 0           1      False    318

# %%
#df.drop(columns=["Total"], inplace=True)

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

# %%
df.head(1)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
df[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["HP"] > 40)].reset_index(drop=True)
# Out:
#       #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0     1              Bulbasaur  Grass  Poison    318   45      49       49
# 1     2                Ivysaur  Grass  Poison    405   60      62       63
# 2     3               Venusaur  Grass  Poison    525   80      82       83
# 3     3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4    43                 Oddish  Grass  Poison    320   45      50       55
# 5    44                  Gloom  Grass  Poison    395   60      65       70
# 6    45              Vileplume  Grass  Poison    490   75      80       85
# 7    69             Bellsprout  Grass  Poison    300   50      75       35
# 8    70             Weepinbell  Grass  Poison    390   65      90       50
# 9    71             Victreebel  Grass  Poison    490   80     105       65
# 10  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
df[~df["Name"].str.contains("Mega")]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df[df["Type 1"].str.contains("fire|grass", flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df["Name"].str.contains("^pi[a-z]*", flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
df.loc[df["Type 1"] == "Fire", "Type 1"] = "Flamer"

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
df.groupby('Type 1').mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Flamer    327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df[df["Legendary"]].sort_values("Attack", ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 429  386     DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 711  646     KyuremBlack Kyurem   Dragon       Ice    700  125     170
# ..   ...                    ...      ...       ...    ...  ...     ...
# 416  379              Registeel    Steel       NaN    580   80      75
# 264  245                Suicune    Water       NaN    580  100      75
# 537  480                   Uxie  Psychic       NaN    580   75      75
# 430  386    DeoxysDefense Forme  Psychic       NaN    600   50      70
# 415  378                 Regice      Ice       NaN    580   80      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.groupby(["Type 1", "Type 2"]).count().reset_index()
# Out:
#     Type 1    Type 2   #  Name  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      Bug  Electric   2     2      2   2       2        2        2        2
# 1      Bug  Fighting   2     2      2   2       2        2        2        2
# 2      Bug      Fire   2     2      2   2       2        2        2        2
# 3      Bug    Flying  14    14     14  14      14       14       14       14
# 4      Bug     Ghost   1     1      1   1       1        1        1        1
# ..     ...       ...  ..   ...    ...  ..     ...      ...      ...      ...
# 131  Water       Ice   3     3      3   3       3        3        3        3
# 132  Water    Poison   3     3      3   3       3        3        3        3
# 133  Water   Psychic   5     5      5   5       5        5        5        5
# 134  Water      Rock   4     4      4   4       4        4        4        4
# 135  Water     Steel   1     1      1   1       1        1        1        1
#
#      Speed  Generation  Legendary
# ...

# %%
standardization = lambda x: (x - x.mean()) / x.std()

# %%
df.groupby('Type 1').HP.transform(standardization)
# Out:
# 0     -1.141155
# 1     -0.372577
# 2      0.652193
# 3      0.652193
# 4     -1.592643
#          ...
# 795   -0.737435
# 796   -0.737435
# 797    0.329626
# 798    0.329626
# 799    0.520310
# Name: HP, Length: 800, dtype: float64

# %%
df.head(1)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
df[df["Type 1"] == "Grass"].HP.mean()
# Out:
# 67.27142857142857

# %%
df[df["Type 1"] == "Grass"].HP.std()
# Out:
# 19.516564074957593

# %%
(df.HP - 67.27142857142857) / 19.516564074957593
# Out:
# 0     -1.141155
# 1     -0.372577
# 2      0.652193
# 3      0.652193
# 4     -1.448586
#          ...
# 795   -0.884963
# 796   -0.884963
# 797    0.652193
# 798    0.652193
# 799    0.652193
# Name: HP, Length: 800, dtype: float64
